# %%
class Node:
    def __init__(self, name):
        self.name = name
        self.next = None

class CircularLinkedList:
    def __init__(self):
        self.head = None

    def append(self, name):
        new_node = Node(name)
        if not self.head:
            self.head = new_node
            self.head.next = self.head
        else:
            temp = self.head
            while temp.next != self.head:
                temp = temp.next
            temp.next = new_node
            new_node.next = self.head

    def print_schedule(self, days=14):
        if not self.head:
            print("Jadwal kosong.")
            return

        temp = self.head
        for day in range(1, days + 1):
            print(f"Hari {day}: {temp.name}")
            for _ in range(3):
                temp = temp.next


satpam_list = CircularLinkedList()
for i in range(4):
    name = input(f"Masukkan nama satpam ke-{i+1}: ")
    satpam_list.append(name)


print("\n\U0001F4C5 Jadwal Piket Satpam Selama 2 Minggu:\n")
satpam_list.print_schedule(14)
# Out:
# Masukkan nama satpam ke-1: Akmal Firadus
# Masukkan nama satpam ke-2: Salwa Fijri
# Masukkan nama satpam ke-3: Hammam Al Rosyid
# Masukkan nama satpam ke-4: Muhammad Abdilah
#
# 📅 Jadwal Piket Satpam Selama 2 Minggu:
#
# Hari 1: Akmal Firadus
# Hari 2: Muhammad Abdilah
# Hari 3: Hammam Al Rosyid
# Hari 4: Salwa Fijri
# Hari 5: Akmal Firadus
# Hari 6: Muhammad Abdilah
# Hari 7: Hammam Al Rosyid
# Hari 8: Salwa Fijri
# Hari 9: Akmal Firadus
# Hari 10: Muhammad Abdilah
# Hari 11: Hammam Al Rosyid
# Hari 12: Salwa Fijri
# Hari 13: Akmal Firadus
# Hari 14: Muhammad Abdilah
