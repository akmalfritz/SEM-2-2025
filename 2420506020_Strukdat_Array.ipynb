# %%
# Deklarasi
data = []

# Inisialisasi elemen
angka = [10,20,30,40,50]

# Menampilkan isi
print("isi array angka:", angka)
# Out:
# isi array angka: [10, 20, 30, 40, 50]

# %%
# Latihan 1
# Deklarasi
Data = []

# Inisialisasi
NPM = [2420506020,2420506021,2420506022,2420506023,2420506024]

#Menampilkan isi
print("isi array NPM:", NPM)
# Out:
# isi array NPM: [2420506020, 2420506021, 2420506022, 2420506023, 2420506024]

# %%
# Mengakses elemen
print("Elemen pertana:", NPM[0])
print("Elemen ke-3:", NPM[2])
print("Elemen terakhir:", NPM[-1])
# Out:
# Elemen pertana: 2420506020
# Elemen ke-3: 2420506022
# Elemen terakhir: 2420506024

# %%
# Menambahkan Elemen append
NPM.append(2420506025)
print("Isi array NPM:", NPM)

# Insert
NPM.insert(3,2420506026)
print("Isi array NPM:", NPM)
# Out:
# Isi array NPM: [2420506020, 2420506021, 2420506022, 2420506023, 2420506024, 2420506025, 2420506025]
# Isi array NPM: [2420506020, 2420506021, 2420506022, 2420506026, 2420506023, 2420506024, 2420506025, 2420506025]

# %%
 Latihan 2
angka = [10,20,30,40,50]
angka.append(20)
print("Isi array angka:", angka)

# Remove
angka.pop(0)
print("Isi array angka:", angka)
# Out:
# Isi array angka: [10, 20, 30, 40, 50, 20]
# Isi array angka: [20, 30, 40, 50, 20]

# %%
# Coba fungsi
angka = [10,20,30,40,50]
angka.append(20)
print("Isi array angka:", angka)

# Remove
angka.remove(10)
print("Isi array angka:", angka)

# pop
angka.pop()
print("Isi array angka:", angka)

# ubah
angka[0] = 100
print("Isi array angka:", angka)
# Out:
# Isi array angka: [10, 20, 30, 40, 50, 20]
# Isi array angka: [20, 30, 40, 50, 20]
# Isi array angka: [20, 30, 40, 50]
# Isi array angka: [100, 30, 40, 50]

# %%
# 3
angka = [10,20,30,40,50]

for nilai in angka:
    print(nilai)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
# Latihan 3
fakultas = ["FT", "FISIP", "FE", "FAPET", "FKIP"]
for nama in fakultas:
    print("Nama Fakultas:", nama)
# Out:
# Nama Fakultas: FT
# Nama Fakultas: FISIP
# Nama Fakultas: FE
# Nama Fakultas: FAPET
# Nama Fakultas: FKIP

# %%
# 4
angka = [10,20,30,40]

print("Jumlah total:", sum(angka))
print("Nilai Terbesar:", max(angka))
print("Nilai Terkecil:", min(angka))
# Out:
# Jumlah total: 100
# Nilai Terbesar: 40
# Nilai Terkecil: 10

# %%
# Latihan 4
harga = [10000, 20000, 30000, 40000, 50000]

print("Jumlah total:", sum(harga))
# Out:
# Jumlah total: 150000

# %%
# 5 Array 2D
matriks = [
    [1,2,3],
    [4,5,6],
    [7,8,9],
]

print("isi array 2D:")
for baris in matriks:
    for kolom in baris:
        print(kolom, end=" ")
    print()
# Out:
# isi array 2D:
# 1 2 3
# 4 5 6
# 7 8 9

# %%
# Latihan 5

matriks = [
    [1,3,4,7],
    [2,4,6,8],
    [3,6,9,12],
]

print("isi array 2D:")
for baris in matriks:
      print(baris)
# Out:
# isi array 2D:
# [1, 3, 4, 7]
# [2, 4, 6, 8]
# [3, 6, 9, 12]

# %%
# 6
matriks = [
    [1,2,3],
    [4,5,6],
    [7,8,9],
]

print("elemen pada baris 1, kolom 2:", matriks[0][1])
# Out:
# elemen pada baris 1, kolom 2: 2

# %%
# LATIHAN 6
matriks = [
    [1,3,4,7],
    [2,4,6,8],
    [3,6,9,12],
]


print("elemen pada baris 2, kolom 4:", matriks[1][3])
# Out:
# elemen pada baris 2, kolom 4: 8

# %%
# LATIHAN 7
matriks = [
    [1,3,4,7],
    [2,4,6,8],
    [3,6,9,12],
]

matriks.append([25,5,2,6])
print("isi array 2D:")
for baris in matriks:
      print(baris)
# Out:
# isi array 2D:
# [1, 3, 4, 7]
# [2, 4, 6, 8]
# [3, 6, 9, 12]
# [25, 5, 2, 6]

# %%
# LATIHAN 8
matriks = [
    [1,3,4,7],
    [2,4,6,8],
    [3,6,9,12],
]

matriks[-1].pop(2)
print("isi array 2D:")
for baris in matriks:
      print(baris)
# Out:
# isi array 2D:
# [1, 3, 4, 7]
# [2, 4, 6, 8]
# [3, 6, 12]

# %%
# LATIHAN 9
matriks = [
    [1,3,4,7],
    [2,4,6,8],
    [3,6,9,12],
]
tanggal_hari_ini = 18

matriks[-1][-1] = tanggal_hari_ini
print("isi array 2D:")
for baris in matriks:
      print(baris)
# Out:
# isi array 2D:
# [1, 3, 4, 7]
# [2, 4, 6, 8]
# [3, 6, 9, 18]

# %%
# LATIHAN 10

daftar_belanja = ["susu", "kopi", "aqua"]
daftar_belanja.append("sabun")
daftar_belanja.remove("kopi")
print("isi daftar belanja:", daftar_belanja)
# Out:
# isi daftar belanja: ['susu', 'aqua', 'sabun']
